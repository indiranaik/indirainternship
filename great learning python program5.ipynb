# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
marvel=pd.read_csv('charcters_stats.csv')

# %%
marvel.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 4  Abomination       bad            63        80     53          90     55
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      95    436

# %%
marvel['Alignment'].value_counts()
# Out:
# good       432
# bad        165
# neutral     11
# Name: Alignment, dtype: int64

# %%
marvel[marvel['Alignment']=='good'].value_counts()
# Out:
# Name         Alignment  Intelligence  Strength  Speed  Durability  Power  Combat  Total
# 3-D Man      good       50            31        43     32          25     52      233      1
# Namora       good       50            85        42     42          41     64      324      1
# Nova         good       38            60        100    100         100    25      423      1
# Northstar    good       50            18        83     56          70     70      347      1
# Nite Owl II  good       1             1         1      1           0      1       5        1
#                                                                                           ..
# Doctor Fate  good       81            16        25     80          100    50      352      1
# Doc Samson   good       75            80        33     80          36     70      374      1
# Deathlok     good       69            32        30     70          40     60      301      1
# ...

# %%
marvel[marvel['Alignment']=='good']
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0            3-D Man      good            50        31     43          32
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 6        Adam Monroe      good            63        10     12         100
# ..               ...       ...           ...       ...    ...         ...
# 604            X-Man      good            88        53     53          95
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
#
#      Power  Combat  Total
# 0       25      52    233
# ...

# %%
good=marvel[marvel['Alignment']=='good']

# %%
good.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 6  Adam Monroe      good            63        10     12         100     71
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 6      64    320

# %%
good.sort_values(by=['Speed'],ascending=False)
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 231       Flash III      good            63        10    100          60
# 304  Jack of Hearts      good            63        55    100          30
# 295         Impulse      good            50        10    100          60
# 525        Stardust      good            88        85    100         110
# 447     Quicksilver      good            63        28    100          60
# ..              ...       ...           ...       ...    ...         ...
# 280       Hellstorm      good             1         1      1           1
# 445         Quantum      good             1         1      1           1
# 277   Hawkwoman III      good             1         1      1           1
# 276    Hawkwoman II      good             1         1      1           1
# 405           Namor      good             1         1      1           1
#
#      Power  Combat  Total
# 231     83      32    348
# 304     70      30    348
# ...

# %%
good.sort_values(by=['Speed'],ascending=False).head()
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 231       Flash III      good            63        10    100          60
# 304  Jack of Hearts      good            63        55    100          30
# 295         Impulse      good            50        10    100          60
# 525        Stardust      good            88        85    100         110
# 447     Quicksilver      good            63        28    100          60
#
#      Power  Combat  Total
# 231     83      32    348
# 304     70      30    348
# 295     63      60    343
# 525    100      85    568
# 447     57      56    364

# %%
good_max_power_full=good[good['Power']==100]

# %%
good_max_power_full.head()
# Out:
#               Name Alignment  Intelligence  Strength  Speed  Durability  \
# 69   Beta Ray Bill      good            63        80     35          95
# 70        Beyonder      good            88       100     23         100
# 85      Black Bolt      good            75        67    100          84
# 129          Cable      good            88        48     23          56
# 185        Deadman      good            50        10     33         100
#
#      Power  Combat  Total
# 69     100      84    457
# 70     100      56    467
# 85     100      56    482
# 129    100      80    395
# 185    100      42    335

# %%
good_max_power_full.shape
# Out:
# (33, 9)

# %%
good_max_power=good.sort_values(by=['Total'],ascending=False)

# %%
good_max_power.head()
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 361  Martian Manhunter      good           100       100     96         100
# 537           Superman      good           100       100    100         100
# 525           Stardust      good            88        85    100         110
# 546               Thor      good            69       100     92         100
# 536          Supergirl      good            94        98     92         100
#
#      Power  Combat  Total
# 361    100      85    581
# 537     94      85    579
# 525    100      85    568
# 546    100      85    546
# 536     85      75    544

# %% [markdown]
# # barplot

# %%
plt.figure(figsize=(8,5))
plt.bar(list(good_max_power['Name'])[0:5],list(good_max_power['Total'])[0:5],color='g')
plt.show()

# %%
bad=marvel[marvel['Alignment']=='bad']

# %%
bad.head()
# Out:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 4   Abomination       bad            63        80     53          90     55
# 5       Abraxas       bad            88       100     83          99    100
# 11   Air-Walker       bad            50        85    100          85    100
# 16        Amazo       bad            75       100    100         100    100
# 17         Ammo       bad             1         1      1           1      0
#
#     Combat  Total
# 4       95    436
# 5       56    526
# 11      40    460
# 16     100    575
# 17       1      5

# %%
bad.sort_values(by=['Speed'],ascending=False).head()
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 610            Zoom       bad            50        10    100          28
# 11       Air-Walker       bad            50        85    100          85
# 16            Amazo       bad            75       100    100         100
# 535  Superboy-Prime       bad            94       100    100         100
# 242     General Zod       bad            94       100     96         100
#
#      Power  Combat  Total
# 610     72      28    288
# 11     100      40    460
# 16     100     100    575
# 535    100      85    579
# 242     94      95    579

# %%
bad.sort_values(by=['Intelligence'],ascending=False).head()
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 386  Mister Mxyzptlk       bad           113        10     12          14
# 338       Lex Luthor       bad           100        10     12          14
# 336           Leader       bad           100        10     12          14
# 122         Brainiac       bad           100        28     63          90
# 194      Doctor Doom       bad           100        32     20         100
#
#      Power  Combat  Total
# 386    100      28    277
# 338     10      28    174
# 336     58      42    236
# 122     60      75    416
# 194     93      84    429

# %%
bad.sort_values(by=['Total'],ascending=False).head()
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 535  Superboy-Prime       bad            94       100    100         100
# 242     General Zod       bad            94       100     96         100
# 16            Amazo       bad            75       100    100         100
# 203        Dormammu       bad            88        95     83         100
# 201        Doomsday       bad            88        80     67         120
#
#      Power  Combat  Total
# 535    100      85    579
# 242     94      95    579
# 16     100     100    575
# 203    100      80    546
# 201    100      90    545

# %%
bad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 165 entries, 4 to 610
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          165 non-null    object
#  1   Alignment     165 non-null    object
#  2   Intelligence  165 non-null    int64
#  3   Strength      165 non-null    int64
#  4   Speed         165 non-null    int64
#  5   Durability    165 non-null    int64
#  6   Power         165 non-null    int64
#  7   Combat        165 non-null    int64
#  8   Total         165 non-null    int64
# dtypes: int64(7), object(2)
# memory usage: 12.9+ KB

# %%
for col in bad.columns:
        print(col)
# Out:
# Name
# Alignment
# Intelligence
# Strength
# Speed
# Durability
# Power
# Combat
# Total

# %%
bad.columns
# Out:
# Index(['Name', 'Alignment', 'Intelligence', 'Strength', 'Speed', 'Durability',
#        'Power', 'Combat', 'Total'],
#       dtype='object')

# %% [markdown]
# # histogram for speed good superheroes

# %%
plt.figure(figsize=(10,5))
plt.hist(good['Speed'])
plt.title('distribution of speed')
plt.xlabel('speed')
plt.show()

# %% [markdown]
# #histogram for combat for supervillians

# %%
plt.figure(figsize=(10,5))
plt.hist(bad['Combat'])
plt.title('distribution of combat')
plt.xlabel('combat')
plt.show()

# %%
df.bad
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df.bad
#
# NameError: name 'df' is not defined
